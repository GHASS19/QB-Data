# %% [markdown]
# # 2 QB Data Wrangling

# %% [markdown]
#    ## 2.1 Contents<a id='2.1_Contents'></a>
# * [2 Data wrangling](#2_Data_wrangling)
#   * [2.1 Contents](#2.1_Contents)
#   * [2.2 Introduction](#2.2_Introduction)
#     * [2.2.1 Recap Of Data Science Problem](#2.2.1_Recap_Of_Data_Science_Problem)
#     * [2.2.2 Introduction To Notebook](#2.2.2_Introduction_To_Notebook)
#   * [2.3 Imports](#2.3_Imports)
#   * [2.4 Objectives](#2.4_Objectives)
#   * [2.5 Load The QB Data](#2.5_Load_The_QB_Data)
#     * [2.5.1 Clean the QB Data](#2.5.1_Clean_the_QB_Data)
#     * [2.5.2 Adding Rows](#2.5.2_Adding_Rows)
#     * [2.5.3 Rearrange Columns](#2.5.3_Rearrange_Columns)
#   * [2.6 Explore the Data](#2.6_Explore_the_Data)
#     * [2.6.1 Create Values for the NaN Columns](#2.6.1_Create_Values_for_the_NaN_Columns)
#       * [2.6.1.1 Create Values for td per cmp](#2.6.1.1_Create_Values_for_td_per_cmp)
#       * [2.6.1.2 Create Values for ypc](#2.6.1.2_Create_Values_for_ypc)
#       * [2.6.1.3 Create Values for QB Rating](#2.6.1.3_Create_Values_for_QB_Rating)
#     * [2.6.2 Looking at NaN Values](#2.6.2_Looking_at_NaN_Values)
#   * [2.7 Explore the Columns](#2.7_Explore_the_Columns)
#       * [2.7.1 QB Column](#2.7.1_QB_Column)
#       * [2.7.2 CMP Column](#2.7.2_CMP_Column)
#       * [2.7.3 ATT Column](#2.7.3_ATT_Column)
#       * [2.7.4 Comp % Column](#2.7.4_Comp_%_Column)

# %% [markdown]
# ## 2.2 Introduction<a id='2.2_Introduction'></a>

# %% [markdown]
# This section is about organizing the QB data and making sure it's well defined. Doing this will help imensely in the future to get what we need out of the data. Some data cleaning will be done at this stage, but we will get into cleaning more as we understand what we need in later parts of the data exploration.

# %% [markdown]
# ### 2.2.1 Recap Of Data Science Problem<a id='2.2.1_Recap_Of_Data_Science_Problem'></a>

# %% [markdown]
# The purpose of this data science project is to evaluate Quarterbacks in the most efficient manner. A NFL team needs help in assessing the Quarterback position with more information than the usual Passer Rating. The QB position is arguably the most important position on the field as they touch the ball on nearly every play. Their decisions can have a huge effect on the outcome of the game. This model will help teams evaluate the QBs on whom to offer a contract, draft, bench or start.

# %% [markdown]
# ### 2.2.2 Introduction To Notebook<a id='2.2.2_Introduction_To_Notebook'></a>

# %% [markdown]
# In Jupyter notebooks you can work in sequence. Here you can add, edit and rearrange cells around without needing to cross out code or wording. Every new cell is an oppurtunity to express a idea.

# %% [markdown]
# # 2.3 Imports<a id='2.3_Imports'></a>

# %% [markdown]
# Here we will use os, pandas, mathplotlib, seaborn and numpy to access and manipulate the QB data. Placing your imports all together at the start of your notebook means you only need to check one place for your notebook's dependencies.

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 2.4 Objectives<a id='2.4_Objectives'></a>

# %% [markdown]
# There are four objectives:
#
# 1. Do we think we have the correct data for our desired question?
#
# 2. Have we identified the required target value?
#
# 3. Do we have features that are potentially useful?
#
# 4. Are there fundamental issues with the data?

# %% [markdown]
# ## 2.5 Load The QB Data<a id='2.5_Load_The_QB_Data'></a>

# %%
# this is the supplied QB CSV data file 
df= pd.read_csv('QBStats_all.csv')

# %% [markdown]
# Now we need to see the first five lines to see what the data looks like just t make sure everythign looks ok! I noticed that there was NaN value for lg when I called the .info(). We will change that soon.

# %%
#call .head() to see the first few rows 
df.head()
# Out:
#                          qb  att  cmp    yds  ypa  td int   lg  sack  loss  \
# 0  Boomer EsiasonB. Esiason   38   25  237.0  6.2   0   0   20   2.0  11.0
# 1   Jim HarbaughJ. Harbaugh   25   16  196.0  7.8   2   1  35t   0.0   0.0
# 2      Paul JustinP. Justin    8    5   53.0  6.6   0   0   30   1.0  11.0
# 3      Jeff GeorgeJ. George   35   16  215.0  6.1   0   0   55   7.0  53.0
# 4   Kerry CollinsK. Collins   31   17  198.0  6.4   2   0   30   4.0  12.0
#
#    rate  game_points home_away  year
# 0  82.9           13      away  1996
# 1  98.1           20      home  1996
# 2  81.8           20      home  1996
# 3  65.8            6      away  1996
# 4  95.9           29      home  1996

# %% [markdown]
# ### 2.5.1 Clean the QB Data<a id='2.5.1_Clean_the_QB_Data'></a>

# %% [markdown]
# First lets rename 'lg' to 'long' and 'loss' to 'loss_yds' to be clear on what the column represents.

# %%
#rename columns
dict = {'lg': 'long',
       'loss': 'loss_yds'}
 
df.rename(columns=dict,
          inplace=True)

# %% [markdown]
# Here we can see that there is a 't' in the lg column. This represents that the QB had their longest pass of 35 yard pass that resulted into a td. we need to get rid of all the 't' and turn lg into an integer. Also lets change the NaN values of long to 0 since a QB that did not complete a pass was filled in as NaN and needs to be numeric.

# %%
#remove all t from long
df['long'] = df['long'].str.replace('t', '')
#replace all NaN values with 0
df['long'] = df['long'].fillna(0)
#long into a int
df['long']=df.long.astype(int)

# %% [markdown]
# ### 2.5.2 Adding Rows<a id='2.5.2_Adding_Rows'></a>

# %% [markdown]
# We also need to create a few more columns to help us grade a QB on their preformance. Here we will make a column for:
# 1. Completion %
# 2. Yards per completion
# 3. Touchdown passes per attempts %
# 4. Touchdown passes per completion %

# %%
#create completion %
df['comp %'] = df['cmp'] / df['att'] 
df['comp %'] = round(df['comp %']*100,1)


#create yards per completion
df['ypc'] = df['yds'] / df['cmp']
df['ypc'] =round(df['ypc'], 1)


#Touchdown Passes per attempts % = Touchdown Passes / Pass Attempts
df['td_per_att'] = df['td'] / df['att']
df['td_per_att'] =round(df['td_per_att'], 3)


#Touchdown Passes per completion % = Touchdown Passes / Pass completions
df['td_per_cmp'] = df['td'] / df['cmp']
df['td_per_cmp'] =round(df['td_per_cmp'], 3)

# %% [markdown]
# ### 2.5.3 Rearrange Columns<a id='2.5.3_Rearrange_Columns'></a>

# %% [markdown]
# Lets rearrange the columns to make it look nice and put relavant columns next to each other.

# %%
#reargange columns
df = df[['qb', 'cmp', 'att', 'comp %', 'yds', 'td', 'int', 'rate',  'long', 'sack', 'game_points', 
          'ypa','ypc', 'td_per_cmp', 'td_per_att', 'loss_yds', 'home_away', 'year']]

# %% [markdown]
# Lets take a look at the four new columns, the rearganed columns and to see if the 't' was removed from the long column.

# %%
df.head()
# Out:
#                          qb  cmp  att  comp %    yds  td int  rate  long  \
# 0  Boomer EsiasonB. Esiason   25   38    65.8  237.0   0   0  82.9    20
# 1   Jim HarbaughJ. Harbaugh   16   25    64.0  196.0   2   1  98.1    35
# 2      Paul JustinP. Justin    5    8    62.5   53.0   0   0  81.8    30
# 3      Jeff GeorgeJ. George   16   35    45.7  215.0   0   0  65.8    55
# 4   Kerry CollinsK. Collins   17   31    54.8  198.0   2   0  95.9    30
#
#    sack  game_points  ypa   ypc  td_per_cmp  td_per_att  loss_yds home_away  \
# 0   2.0           13  6.2   9.5       0.000       0.000      11.0      away
# 1   0.0           20  7.8  12.2       0.125       0.080       0.0      home
# 2   1.0           20  6.6  10.6       0.000       0.000      11.0      home
# 3   7.0            6  6.1  13.4       0.000       0.000      53.0      away
# 4   4.0           29  6.4  11.6       0.118       0.065      12.0      home
#
#    year
# 0  1996
# 1  1996
# 2  1996
# 3  1996
# 4  1996

# %% [markdown]
# Looks good!

# %% [markdown]
# ## 2.6 Explore the Data<a id='2.6_Explore_the_Data'></a>

# %% [markdown]
# Count the number of missing values in each column and sort them.

# %%
missing = pd.concat([df.isnull().sum(), 100 * df.isnull().mean()], axis=1)
missing.columns=["count", '%']
missing.sort_values(by='count', ascending=False)
# Out:
#              count         %
# td_per_cmp     719  5.451926
# ypc            719  5.451926
# comp %          97  0.735517
# td_per_att      97  0.735517
# sack            17  0.128905
# loss_yds        17  0.128905
# rate            17  0.128905
# game_points      0  0.000000
# home_away        0  0.000000
# ypa              0  0.000000
# qb               0  0.000000
# cmp              0  0.000000
# long             0  0.000000
# int              0  0.000000
# td               0  0.000000
# yds              0  0.000000
# att              0  0.000000
# year             0  0.000000

# %% [markdown]
# td_per_comp and ypc, (yards per catch) have the most missing values at 5.45%. Comp % and td_per_att are missing .735% of their respective data. Sack, loss_yds, and rate are missing an equal amount as well at .128%. We need to investigate the missing data and decide what to enter for this missing data. Sucn as zero, the mean or something else.

# %%
df[df.isnull().any(axis=1)]
# Out:
#                                   qb  cmp  att  comp %  yds  td int  rate  \
# 19         Kordell StewartK. Stewart    0    2     0.0  0.0   0   0  39.6
# 28               Elvis GrbacE. Grbac    0    2     0.0  0.0   0   0  39.6
# 32          Bill MusgraveB. Musgrave    0    1     0.0  0.0   0   0  39.6
# 55                   Tom TupaT. Tupa    0    1     0.0  0.0   0   0  39.6
# 66        Sean SalisburyS. Salisbury    0    1     0.0  0.0   0   1   0.0
# ...                              ...  ...  ...     ...  ...  ..  ..   ...
# 13126  Larry FitzgeraldL. Fitzgerald    0    1     0.0  0.0   0   0  39.6
# 13156    Antonio MorrisonA. Morrison    0    1     0.0  0.0   0   0  39.6
# 13158    Jimmy GaroppoloJ. Garoppolo    0    1     0.0  0.0   0   0  39.6
# 13164              Shaun HillS. Hill    0    1     0.0  0.0   0   0  39.6
# 13179         Pharoh CooperP. Cooper    0    1     0.0  0.0   0   1   0.0
#
#        long  sack  game_points  ypa  ypc  td_per_cmp  td_per_att  loss_yds  \
# 19        0   0.0            9  0.0  NaN         NaN         0.0       0.0
# 28        0   0.0           27  0.0  NaN         NaN         0.0       0.0
# 32        0   0.0           31  0.0  NaN         NaN         0.0       0.0
# 55        0   0.0           10  0.0  NaN         NaN         0.0       0.0
# 66        0   0.0           27  0.0  NaN         NaN         0.0       0.0
# ...     ...   ...          ...  ...  ...         ...         ...       ...
# 13126     0   0.0           34  0.0  NaN         NaN         0.0       0.0
# 13156     0   0.0           24  0.0  NaN         NaN         0.0       0.0
# 13158     0   0.0           35  0.0  NaN         NaN         0.0       0.0
# 13164     0   0.0           38  0.0  NaN         NaN         0.0       0.0
# 13179     0   0.0            6  0.0  NaN         NaN         0.0       0.0
#
#       home_away  year
# 19         away  1996
# 28         home  1996
# 32         home  1996
# 55         away  1996
# 66         home  1996
# ...         ...   ...
# 13126      away  2016
# 13156      home  2016
# 13158      away  2016
# 13164      home  2016
# 13179      home  2016
#
# [736 rows x 18 columns]

# %% [markdown]
# Here we can see that the 97 comp % and td_per att are NaN values because they did not throw a pass but were credited as having a sack, (where they were going to attempt a pass but never even made it). These 97 data points dont really help us to determine a Qb rating system. We should get rid of these values since they are outliers during the data clean phase.
#
# The loss_yds and sack are correlated with 17 NaN values since the QB is accredited with loss yards for every sack that occurs. A sack is when a QB drops back to pass but is tackle behind the line of scrimmage. We will fill them in with 0s since they still have other relavant data.
#
# The rate, td_per_cmp and ypc columns do not show any NaN values.

# %% [markdown]
# ### 2.6.1 Create Values for the NaN Columns<a id='2.6.1_Create_Values_for_the_NaN_Columns'></a>

# %% [markdown]
# 1. Lets take a look at the Interception 'int' column first. AN interception is when a QB throws the ball to the other team.

# %%
df['int'].value_counts()
# Out:
# 0     6384
# 1     4089
# 2     1870
# 3      624
# 4      166
# 5       32
# --      17
# 6        5
# 7        1
# Name: int, dtype: int64

# %% [markdown]
# Here we will enter 0 for the '--'. We can assume they meant that the QB did not have an interception for that particular game.

# %%
df['int'] = df['int'].replace('--', 0)

# %% [markdown]
# We need to turn the 'int' into a integer as well.

# %%
#int into float
df['int']=df.int.astype(int)

# %% [markdown]
# ### 2.6.1.1 Create Values for td per cmp<a id='2.6.1.1_Create_Values_for_td_per_cmp'></a>

# %% [markdown]
# 2. Now lets look at the touchdown per completion/'td_per_cmp' column.

# %%
pd.set_option("display.max_rows", None)
df['td_per_cmp'].value_counts()
# Out:
# 0.000    4077
# 0.100     308
# 0.083     304
# 0.111     304
# 0.125     291
# 0.077     286
# 0.067     285
# 0.059     283
# 0.091     283
# 0.143     283
# 0.071     281
# 0.062     278
# 0.056     265
# 0.053     246
# 0.045     240
# 0.050     234
# 0.048     232
# 0.043     207
# 0.167     205
# 0.095     181
# 0.105     177
# 0.087     162
# 0.118     162
# 0.042     160
# 0.133     153
# 0.200     139
# 1.000     136
# 0.080     127
# 0.040     127
# 0.038     104
# 0.074      99
# 0.136      86
# 0.250      77
# 0.036      74
# 0.037      74
# 0.150      71
# 0.154      71
# 0.182      70
# 0.034      68
# 0.130      65
# 0.069      63
# 0.120      61
# 0.158      61
# 0.115      57
# 0.188      55
# 0.176      50
# 0.033      49
# 0.103      43
# 0.222      42
# 0.333      41
# 0.107      37
# 0.032      37
# 0.065      29
# 0.029      29
# 0.031      29
# 0.174      27
# 0.214      24
# 0.097      22
# 0.190      22
# 0.160      21
# 0.057      21
# 0.231      21
# 0.061      20
# 0.148      20
# 0.273      19
# 0.235      19
# 0.500      18
# 0.138      17
# 0.030      17
# 0.211      15
# 0.286      15
# 0.094      14
# 0.088      14
# 0.086      11
# 0.028       9
# 0.054       9
# 0.129       8
# 0.026       7
# 0.267       7
# 0.300       7
# 0.179       7
# 0.227       6
# 0.192       6
# 0.238       6
# 0.208       6
# 0.217       5
# 0.139       4
# 0.278       4
# 0.081       4
# 0.263       4
# 0.121       4
# 0.161       4
# 0.079       3
# 0.073       3
# 0.400       3
# 0.027       3
# 0.051       3
# 0.308       3
# 0.156       2
# 0.185       2
# 0.294       2
# 0.108       2
# 0.385       2
# 0.364       2
# 0.075       2
# 0.318       1
# 0.194       1
# 0.259       1
# 0.240       1
# 0.114       1
# 0.116       1
# 0.667       1
# 0.025       1
# 0.022       1
# 0.207       1
# 0.429       1
# 0.261       1
# 0.023       1
# 0.375       1
# 0.047       1
# Name: td_per_cmp, dtype: int64

# %%
#replace all td per cmp NaN values with 0
df['td_per_cmp'] = df['td_per_cmp'].fillna(0)

# %% [markdown]
# The 'td_per_cmp' column looks good!

# %% [markdown]
# ### 2.6.1.2 Create Values for ypc<a id='2.6.1.2_Create_Values_for_ypc'></a>

# %% [markdown]
# 3. Lets look at the yards per completion/'ypc' column

# %%
pd.set_option("display.max_rows", None)
df['ypc'].value_counts()
# Out:
#  11.0    227
#  10.0    225
#  11.1    221
#  11.5    203
#  10.8    198
#  11.2    197
#  10.6    195
#  12.2    195
#  10.4    195
#  12.0    193
#  11.6    186
#  10.5    183
#  11.4    183
#  11.3    182
#  11.8    179
#  10.2    176
#  10.9    176
#  9.8     174
#  10.7    171
#  11.7    169
#  9.6     167
#  9.0     166
#  10.1    165
#  9.9     162
#  12.1    162
#  9.4     159
#  12.4    158
#  11.9    156
#  10.3    156
#  13.0    152
#  12.8    150
#  9.5     147
#  9.3     144
#  12.7    140
#  12.5    139
#  12.9    138
#  9.2     135
#  12.3    134
#  9.7     134
#  12.6    130
#  8.8     130
#  9.1     129
#  13.2    126
#  14.0    125
#  8.0     122
#  8.9     116
#  13.6    115
#  13.5    113
#  13.4    112
#  13.8    111
#  13.1    106
#  8.6     103
#  8.7     101
#  8.2      97
#  8.5      94
#  14.2     93
#  13.3     93
#  13.7     92
#  8.4      88
#  13.9     87
#  14.4     81
#  14.1     79
#  14.8     78
#  7.0      77
#  15.0     77
#  14.3     75
#  7.8      73
#  14.5     72
#  14.7     71
#  14.6     71
#  8.3      68
#  8.1      65
#  14.9     61
#  7.5      60
#  15.2     60
#  6.0      60
#  7.6      60
#  15.1     57
#  7.7      56
#  16.0     55
#  7.2      52
#  7.9      52
#  15.4     51
#  4.0      51
#  16.2     50
#  5.0      49
#  15.5     48
#  15.6     48
#  15.3     47
#  17.0     47
#  7.4      46
#  7.3      43
#  15.9     43
#  15.7     42
#  3.0      39
#  16.5     39
#  6.8      38
#  15.8     38
#  18.0     35
# %% [markdown]
# ### 2.6.1.3 Create Values for QB Rating<a id='2.6.1.3_Create_Values_for_QB_Rating'></a>

# %% [markdown]
# 4. Lets look at the  QB rating/'rate' data. A standard QB rating is based on four metrics: completion percentage, yards per passing attempt, touchdown percentage, and interception percentage.

# %%
pd.set_option("display.max_rows", None)
df['rate'].value_counts()
# Out:
# 39.6     579
# 0.0      221
# 118.8    198
# 158.3    130
# 56.2      83
# 79.2      79
# 95.8      51
# 91.7      47
# 87.5      41
# 42.4      40
# 104.2     37
# 68.8      35
# 97.9      34
# 108.3     34
# 83.3      33
# 77.1      32
# 100.0     32
# 85.4      31
# 72.9      30
# 89.6      30
# 60.4      29
# 116.7     29
# 81.1      28
# 78.5      27
# 81.8      27
# 112.5     27
# 81.2      26
# 70.1      26
# 87.8      25
# 76.5      25
# 89.2      25
# 64.6      25
# 88.0      25
# 93.1      25
# 47.9      25
# 58.3      24
# 75.4      24
# 85.3      23
# 72.0      23
# 109.7     23
# 68.2      22
# 81.9      22
# 72.8      22
# 57.0      22
# 88.4      22
# 74.8      22
# 87.0      21
# 74.1      21
# 68.5      21
# 85.0      21
# 102.1     21
# 94.8      21
# 80.2      21
# 84.8      21
# 81.7      21
# 82.3      21
# 79.0      21
# 70.8      21
# 79.6      21
# 99.3      21
# 82.6      20
# 53.0      20
# 94.4      20
# 105.2     20
# 85.7      20
# 68.9      20
# 71.5      20
# 69.0      20
# 82.9      20
# 93.8      20
# 65.6      20
# 104.9     20
# 96.6      20
# 84.2      20
# 91.2      20
# 80.6      20
# 82.1      20
# 92.9      20
# 65.5      20
# 76.2      20
# 94.7      19
# 88.5      19
# 67.9      19
# 75.5      19
# 93.5      19
# 69.7      19
# 65.7      19
# 91.8      19
# 61.0      19
# 67.2      19
# 81.0      19
# 73.3      19
# 93.4      19
# 91.0      19
# 79.7      19
# 79.9      19
# 100.5     19
# 92.4      19
# 78.9      19
# 66.2      19
# 86.4      19
# 61.2      19
# 96.4      19
# 72.5      19
# 110.4     18
# 74.0      18
# 49.2      18
# 71.9      18
# 74.7      18
# 81.4      18
# 74.9      18
# 88.8      18
# 86.8      18
# 100.3     18
# 103.3     18
# 59.2      18
# 102.4     18
# 65.1      18
# 76.0      18
# 81.6      18
# 60.2      18
# 88.7      18
# 106.2     18
# 89.3      18
# 86.5      18
# 127.1     18
# 75.7      18
# 97.5      18
# 106.4     18
# 76.3      18
# 73.6      18
# 77.5      17
# 73.1      17
# 64.4      17
# 110.9     17
# 62.5      17
# 88.6      17
# 72.6      17
# 75.2      17
# 94.2      17
# 83.9      17
# 80.1      17
# 96.8      17
# 81.5      17
# 69.9      17
# 66.9      17
# 100.7     17
# 79.4      17
# 78.8      17
# 64.8      17
# 70.4      17
# 70.0      17
# 96.7      17
# 90.8      17
# 91.5      17
# 97.3      17
# 51.3      17
# 76.4      17
# 84.0      17
# 16.7      17
# 78.0      17
# 54.2      17
# 83.4      17
# 85.6      17
# 51.9      17
# 89.1      17
# 66.3      17
# 65.8      17
# 80.5      16
# 61.8      16
# 97.6      16
# 88.2      16
# 86.3      16
# 83.1      13
# 57.1      13
# 61.6      12
# 73.5      12
# 67.4      12
# 111.2     12
# 67.8      12
# 122.9     12
# 92.7      12
# 50.3      12
# 133.3     12
# 104.4     12
# 95.1      12
# 70.6      12
# 104.1     12
# 58.8      12
# 52.2      12
# 107.4     12
# 68.4      12
# 105.6     12
# 80.0      12
# 95.6      12
# 84.1      12
# 105.8     12
# 100.4     12
# 112.3     12
# 59.9      12
# 74.6      12
# 58.4      12
# 108.6     12
# 75.6      12
# 97.1      12
# 93.0      12
# 56.9      12
# 63.8      12
# 90.1      12
# 109.2     12
# 113.8     12
# 65.9      12
# 65.4      12
# 86.2      12
# 115.1     12
# 115.5     12
# 101.0     12
# 52.1      12
# 41.7      12
# 113.1     12
# 58.2      12
# 43.4      12
# 72.3      12
# 71.2      12
# 94.6      11
# 111.7     11
# 83.2      11
# 64.0      11
# 143.8     11
# 61.3      11
# 55.9      11
# 122.1     11
# 65.3      11
# 61.4      11
# 93.2      11
# 117.7     11
# 78.7      11
# 80.3      11
# 102.8     11
# 85.9      11
# 147.9     11
# 107.5     11
# 107.1     11
# 91.3      11
# 53.5      11
# 57.9      11
# 98.0      11
# 102.7     11
# 75.1      11
# 66.8      11
# 75.0      11
# 71.8      11
# 104.7     11
# 106.6     11
# 111.9     11
# 51.0      11
# 53.8      11
# 86.0      11
# 90.4      11
# 50.4      11
# 88.9      11
# 129.6     11
# 55.5      11
# 54.7      11
# 98.4      11
# 49.9      11
# 58.9      11
# 110.6     11
# 62.1      11
# 59.7      11
# 76.7      11
# 82.5      11
# 105.5     11
# 101.2     11
# 92.3      11
# 95.9      11
# 104.0     11
# 53.3      11
# 55.7      10
# 44.9      10
# 43.1      10
# 111.8     10
# 61.5      10
# 108.4     10
# 125.0     10
# 109.4     10
# 62.4      10
# 110.1     10
# 63.9      10
# 64.1      10
# 94.9      10
# 67.3      10
# 63.1      10
# 90.9      10
# 121.0     10
# 64.3      10
# 108.7     10
# 53.9      10
# 96.1      10
# 107.9     10
# 55.1      10
# 52.5      10
# 44.6      10
# 106.8     10
# 50.2      10
# 99.6      10
# 92.6      10
# 69.1      10
# 38.9      10
# 72.2      10
# 87.2      10
# 64.2      10
# 91.6      10
# 135.4     10
# 63.3      10
# 76.9      10
# 47.2      10
# 112.1     10
# 109.8     10
# 109.6     10
# 145.8     10
# 62.6      10
# 105.4     10
# 54.4      10
# 107.3     10
# 51.2      10
# 117.2     10
# 120.3     10
# 94.0      10
# 139.6     10
# 97.4      10
# 112.7     10
# 45.7      10
# 55.4      10
# 54.0      10
# 2.8       10
# 96.2      10
# 73.2      10
# 61.9      10
# 58.0      10
# 43.8      10
# 46.9      10
# 63.4      10
# 116.8     10
# 94.5      10
# 29.2      10
# 59.1       9
# 78.4       9
# 117.4      9
# 57.4       9
# 116.2      9
# 45.4       9
# 46.5       9
# 46.8       9
# 123.3      9
# 58.5       9
# 103.4      9
# 110.3      9
# 59.4       9
# 80.7       9
# 114.2      9
# 39.8       9
# 114.0      9
# 106.1      9
# 34.3       9
# 112.6      9
# 56.0       9
# 54.8       9
# 51.5       9
# 116.4      9
# 102.3      9
# 59.3       9
# 98.3       9
# 120.7      9
# 55.6       9
# 90.5       9
# 58.1       9
# 99.2       9
# 90.3       9
# 57.6       9
# 122.3      9
# 101.3      9
# 103.2      9
# 70.7       9
# 123.2      9
# 53.7       9
# 98.8       9
# 44.5       9
# 117.6      9
# 87.7       9
# 115.8      9
# 33.5       9
# 97.2       9
# 41.9       9
# 119.2      9
# 102.9      9
# 49.4       9
# 79.1       9
# 119.8      9
# 40.4       9
# 38.1       8
# 68.6       8
# 49.8       8
# 107.7      8
# 103.5      8
# 119.1      8
# 62.0       8
# 40.6       8
# 124.7      8
# 149.3      8
# 156.2      8
# 48.8       8
# 100.9      8
# 108.5      8
# 125.4      8
# 123.1      8
# 89.7       8
# 112.2      8
# 140.0      8
# 64.5       8
# 125.1      8
# 71.3       8
# 118.9      8
# 118.1      8
# 59.6       8
# 50.1       8
# 119.9      8
# 104.5      8
# 99.5       8
# 55.0       8
# 109.1      8
# 66.4       8
# 102.5      8
# 103.8      8
# 57.3       8
# 111.3      8
# 48.3       8
# 49.5       8
# 95.0       8
# 104.6      8
# 47.8       8
# 64.9       8
# 103.7      8
# 115.7      8
# 111.1      8
# 48.1       8
# 44.2       8
# 115.9      8
# 61.7       8
# 114.8      8
# 138.9      8
# 115.2      8
# 92.2       8
# 113.0      8
# 128.2      8
# 115.0      8
# 121.9      8
# 95.4       8
# 48.7       8
# 54.6       8
# 51.6       8
# 124.4      8
# 48.5       8
# 99.8       8
# 112.4      8
# 47.6       8
# 38.6       8
# 66.6       8
# 122.2      8
# 49.7       8
# 125.6      8
# 126.4      8
# 124.1      8
# 49.3       8
# 117.0      8
# 61.1       8
# 117.9      8
# 106.7      8
# 118.6      8
# 109.3      7
# 66.1       7
# 115.4      7
# 113.5      7
# 43.9       7
# 137.0      7
# 36.6       7
# 105.9      7
# 57.5       7
# 50.9       7
# 48.9       7
# 121.4      7
# 105.0      7
# 44.8       7
# 126.0      7
# 77.3       7
# 130.0      7
# 118.2      7
# 123.7      7
# 105.1      7
# 107.2      7
# 118.5      7
# 45.6       7
# 42.0       7
# 51.4       7
# 42.8       7
# 121.8      7
# 120.0      7
# 110.8      7
# 129.2      7
# 50.6       7
# 127.7      7
# 31.2       7
# 43.5       7
# 116.9      7
# 60.5       7
# 52.0       7
# 124.5      7
# 114.4      7
# 48.6       7
# 101.6      7
# 8.3        7
# 136.7      7
# 77.0       7
# 42.9       7
# 120.1      7
# 46.1       7
# 124.2      7
# 73.0       7
# 55.3       7
# 112.8      7
# 113.3      7
# 14.6       7
# 38.7       7
# 38.4       7
# 50.7       7
# 37.3       7
# 114.9      7
# 115.6      7
# 55.8       7
# 54.3       7
# 46.2       7
# 113.2      7
# 54.5       7
# 30.6       7
# 52.3       7
# 108.1      7
# 127.6      7
# 117.5      7
# 62.7       7
# 127.9      7
# 56.5       7
# 123.4      7
# 45.1       7
# 18.8       7
# 121.6      7
# 33.6       7
# 35.0       7
# 51.1       7
# 31.0       7
# 46.4       7
# 130.6      7
# 47.7       7
# 110.7      7
# 46.6       7
# 100.6      7
# 45.3       7
# 30.5       6
# 114.1      6
# 43.3       6
# 49.1       6
# 54.9       6
# 19.0       6
# 132.1      6
# 56.6       6
# 123.6      6
# 42.7       6
# 44.0       6
# 117.8      6
# 38.8       6
# 115.3      6
# 119.4      6
# 119.3      6
# 111.6      6
# 34.1       6
# 52.4       6
# 120.5      6
# 117.3      6
# 52.8       6
# 134.4      6
# 117.1      6
# 137.4      6
# 116.3      6
# 34.2       6
# 141.7      6
# 131.6      6
# 131.7      6
# 48.2       6
# 38.3       6
# 52.6       6
# 134.7      6
# 34.5       6
# 113.7      6
# 116.1      6
# 51.7       6
# 44.3       6
# 41.3       6
# 46.3       6
# 130.8      6
# 135.7      6
# 98.2       6
# 120.6      6
# 27.4       6
# 109.5      6
# 120.4      6
# 128.5      6
# 40.9       6
# 25.8       6
# 40.0       6
# 17.3       6
# 22.9       6
# 136.3      6
# 134.5      6
# 108.2      6
# 111.0      6
# 67.1       6
# 44.4       6
# 132.9      6
# 27.7       6
# 116.6      6
# 133.9      6
# 126.8      6
# 45.0       6
# 128.1      6
# 47.5       6
# 123.5      6
# 10.7       5
# 131.8      5
# 126.6      5
# 123.9      5
# 125.5      5
# 126.1      5
# 60.3       5
# 37.8       5
# 121.5      5
# 127.8      5
# 120.2      5
# 137.3      5
# 125.2      5
# 22.2       5
# 122.0      5
# 129.3      5
# 41.1       5
# 47.3       5
# 31.9       5
# 85.5       5
# 127.2      5
# 133.0      5
# 130.9      5
# 119.0      5
# 131.4      5
# 43.6       5
# 128.8      5
# 110.5      5
# 27.3       5
# 22.3       5
# 31.7       5
# 41.2       5
# 37.7       5
# 114.3      5
# 141.9      5
# 29.6       5
# 102.0      5
# 39.1       5
# 46.7       5
# 121.7      5
# 121.2      5
# 37.0       5
# 35.4       5
# 39.2       5
# 56.7       5
# 131.5      5
# 109.9      5
# 49.6       5
# 57.7       5
# 57.8       5
# 131.1      5
# 128.9      5
# 123.8      5
# 131.2      5
# 45.5       5
# 33.3       5
# 128.4      5
# 140.8      5
# 122.7      5
# 112.0      5
# 132.6      5
# 42.5       5
# 23.8       5
# 124.0      5
# 81.3       5
# 113.6      5
# 41.5       5
# 28.0       5
# 6.2        5
# 134.6      5
# 119.6      5
# 126.7      5
# 122.8      5
# 128.6      4
# 17.1       4
# 118.3      4
# 36.5       4
# 148.1      4
# 32.4       4
# 146.0      4
# 139.8      4
# 132.3      4
# 30.2       4
# 113.4      4
# 34.7       4
# 140.6      4
# 36.9       4
# 35.6       4
# 124.6      4
# 129.5      4
# 31.1       4
# 57.2       4
# 27.2       4
# 48.0       4
# 30.4       4
# 35.7       4
# 143.4      4
# 30.9       4
# 40.3       4
# 35.2       4
# 148.3      4
# 139.9      4
# 141.0      4
# 130.5      4
# 33.1       4
# 112.9      4
# 118.0      4
# 122.5      4
# 26.3       4
# 47.0       4
# 36.0       4
# 50.8       4
# 27.1       4
# 27.5       4
# 42.3       4
# 121.1      4
# 41.4       4
# 51.8       4
# 124.3      4
# 127.3      4
# 111.4      4
# 20.5       4
# 20.1       4
# 33.0       4
# 10.2       1
# 20.9       1
# 147.3      1
# 145.0      1
# 20.0       1
# 21.1       1
# 25.5       1
# 8.2        1
# 16.5       1
# 134.3      1
# 18.6       1
# 151.3      1
# 12.6       1
# 149.9      1
# 1.2        1
# 137.9      1
# 147.8      1
# 11.7       1
# 132.7      1
# 24.8       1
# 9.5        1
# 19.8       1
# 8.5        1
# 11.8       1
# 68.7       1
# 134.8      1
# 16.3       1
# 16.9       1
# 32.0       1
# 13.1       1
# 129.8      1
# 22.6       1
# 127.0      1
# 140.9      1
# 32.7       1
# 147.0      1
# 2.5        1
# 23.1       1
# 17.8       1
# 14.0       1
# 153.5      1
# 147.1      1
# 144.6      1
# 154.3      1
# 150.3      1
# 13.6       1
# 13.2       1
# 136.5      1
# 135.5      1
# 7.3        1
# 1.0        1
# 134.9      1
# 18.7       1
# 7.4        1
# 23.3       1
# 21.5       1
# 155.3      1
# 12.4       1
# 9.6        1
# 22.5       1
# 15.9       1
# 123.0      1
# 154.8      1
# 2.1        1
# 8.9        1
# 11.1       1
# 143.0      1
# 22.8       1
# 122.4      1
# 36.1       1
# 0.4        1
# 24.2       1
# 17.5       1
# 126.2      1
# Name: rate, dtype: int64

# %% [markdown]
# Looks like there are no NaN values. We can fill in NaN with 0 just to be sure. Here we have lot of different rate values which is good for our data. This could give us a wide range to determine what makes a QB good or bad.

# %%
#replace all rate NaN values with 0
df['rate'] = df['rate'].fillna(0)

# %% [markdown]
# ### 2.6.2 Looking at NaN Values<a id='2.6.2_Looking_at_NaN_Values'></a>

# %%
missing = pd.concat([df.isnull().sum(), 100 * df.isnull().mean()], axis=1)
missing.columns=["count", '%']
missing.sort_values(by='count', ascending=False)
# Out:
#              count         %
# comp %          97  0.735517
# td_per_att      97  0.735517
# sack            17  0.128905
# loss_yds        17  0.128905
# game_points      0  0.000000
# home_away        0  0.000000
# td_per_cmp       0  0.000000
# ypc              0  0.000000
# ypa              0  0.000000
# qb               0  0.000000
# cmp              0  0.000000
# long             0  0.000000
# rate             0  0.000000
# int              0  0.000000
# td               0  0.000000
# yds              0  0.000000
# att              0  0.000000
# year             0  0.000000

# %% [markdown]
# During the data cleaning phase we will determine what to do with the comp %, td_per_att, sack and loss_yds columns.

# %% [markdown]
# ## 2.7 Explore the Columns<a id='2.7_Explore_the_Columns'></a>

# %% [markdown]
# Here we will find out what the values, range, mean, counts, unique values, median, mode and standard deviation is for each column.

# %% [markdown]
# ### 2.7.1 QB Column<a id='2.7.1_QB_Column'></a>

# %%
df['qb'].dtypes
# Out:
# dtype('O')

# %% [markdown]
# The QB column is an object.

# %%
df['qb'].unique()
# Out:
# array(['Boomer EsiasonB.\xa0Esiason', 'Jim HarbaughJ.\xa0Harbaugh',
#        'Paul JustinP.\xa0Justin', 'Jeff GeorgeJ.\xa0George',
#        'Kerry CollinsK.\xa0Collins', 'Jeff BlakeJ.\xa0Blake',
#        'Steve WalshS.\xa0Walsh', 'Scott MitchellS.\xa0Mitchell',
#        'Mark RoyalsM.\xa0Royals', 'Brad JohnsonB.\xa0Johnson',
#        'Hines WardH.\xa0Ward', 'Leo AraguzL.\xa0Araguz',
#        'Priest HolmesP.\xa0Holmes', 'Moses MorenoM.\xa0Moreno',
#        'Rod SmithR.\xa0Smith', 'Mike HoranM.\xa0Horan',
#        'Tony MartinT.\xa0Martin', 'Terrell FletcherT.\xa0Fletcher',
#        'Mike AlstottM.\xa0Alstott', 'Eric KresserE.\xa0Kresser',
#        'Jonathan QuinnJ.\xa0Quinn', 'Rick TutenR.\xa0Tuten',
#        'Mike CherryM.\xa0Cherry', 'Doug PelfreyD.\xa0Pelfrey',
#        'Wally RichardsonW.\xa0Richardson', 'Torrance SmallT.\xa0Small',
#        'Kurt WarnerK.\xa0Warner', 'Ricky WattersR.\xa0Watters',
#        'Duce StaleyD.\xa0Staley', 'Akili SmithA.\xa0Smith',
#        'Scott CovingtonS.\xa0Covington', 'Brett ConwayB.\xa0Conway',
#        'Cade McNownC.\xa0McNown', 'Jeff GarciaJ.\xa0Garcia',
#        'Pete GonzalezP.\xa0Gonzalez', 'Tim CouchT.\xa0Couch',
#        'Michael PittmanM.\xa0Pittman', 'Donovan McNabbD.\xa0McNabb',
#        'Charlie GarnerC.\xa0Garner', 'Mikhael RicksM.\xa0Ricks',
#        'Matt HasselbeckM.\xa0Hasselbeck', 'Chris GreisenC.\xa0Greisen',
#        'Marshall FaulkM.\xa0Faulk', 'Chris MillerC.\xa0Miller',
#        'Keyshawn JohnsonK.\xa0Johnson', 'Jerald SowellJ.\xa0Sowell',
#        'Shaun KingS.\xa0King', 'Kevin JohnsonK.\xa0Johnson',
#        'Robert ReedR.\xa0Reed', 'Jerome BettisJ.\xa0Bettis',
#        'Frank WycheckF.\xa0Wycheck', 'Jake DelhommeJ.\xa0Delhomme',
#        'Ricky WilliamsR.\xa0Williams', 'Randy MossR.\xa0Moss',
#        'Deion SandersD.\xa0Sanders', 'Troy BrownT.\xa0Brown',
#        'Joe GermaineJ.\xa0Germaine', 'Brock HuardB.\xa0Huard',
#        'Daunte CulpepperD.\xa0Culpepper', 'Robert ChanceyR.\xa0Chancey',
#        'Doug JohnsonD.\xa0Johnson', 'Curtis MartinC.\xa0Martin',
#        'Chris RedmanC.\xa0Redman', 'Clint StoernerC.\xa0Stoerner',
#        'Spergon WynnS.\xa0Wynn', 'Michael BishopM.\xa0Bishop',
#        'Lee JohnsonL.\xa0Johnson', 'Jermaine LewisJ.\xa0Lewis',
#        'Sylvester MorrisS.\xa0Morris', 'Thurman ThomasT.\xa0Thomas',
#        'Joe HamiltonJ.\xa0Hamilton', 'Mitch BergerM.\xa0Berger',
#        'Ahman GreenA.\xa0Green', 'Aaron BrooksA.\xa0Brooks',
#        'Tom BradyT.\xa0Brady', 'Anthony WrightA.\xa0Wright',
#        'Tim RattayT.\xa0Rattay', 'Kevin ThompsonK.\xa0Thompson',
#        'Mark HartsellM.\xa0Hartsell', 'Chad PenningtonC.\xa0Pennington',
#        'Travis BrownT.\xa0Brown', 'Jeff FeaglesJ.\xa0Feagles',
#        'Jarious JacksonJ.\xa0Jackson', 'Todd HusakT.\xa0Husak',
#        'LaBrandon ToefieldL.\xa0Toefield', 'Stacey MackS.\xa0Mack',
#        'LaDainian TomlinsonL.\xa0Tomlinson',
#        'Woodrow DantzlerW.\xa0Dantzler', 'Aveion CasonA.\xa0Cason',
#        'Darren BennettD.\xa0Bennett', 'Anquan BoldinA.\xa0Boldin',
#        'Tim HasselbeckT.\xa0Hasselbeck', 'Nick HarrisN.\xa0Harris',
#        'Dante HallD.\xa0Hall', 'Terry GlennT.\xa0Glenn',
#        'T.J. DuckettT.\xa0Duckett', 'Dave RagoneD.\xa0Ragone',
#        'Bill SchroederB.\xa0Schroeder', 'Rex GrossmanR.\xa0Grossman',
#        'Brant BoyerB.\xa0Boyer', 'Dennis NorthcuttD.\xa0Northcutt',
#        'David GivensD.\xa0Givens', 'Tee MartinT.\xa0Martin',
#        'Gibran HamdanG.\xa0Hamdan', 'Josh MillerJ.\xa0Miller',
#        'Carson PalmerC.\xa0Palmer', 'Ken DorseyK.\xa0Dorsey',
#        'Mat McBriarM.\xa0McBriar', 'Eli ManningE.\xa0Manning',
#        'Steve SmithS.\xa0Smith', 'Ben RoethlisbergerB.\xa0Roethlisberger',
#        'Chris SimmsC.\xa0Simms', 'Luke McCownL.\xa0McCown',
#        'Roy WilliamsR.\xa0Williams', 'Craig NallC.\xa0Nall',
#        'Emmitt SmithE.\xa0Smith', 'Mewelde MooreM.\xa0Moore',
#        'Sammy MorrisS.\xa0Morris', 'Craig KrenzelC.\xa0Krenzel',
#        'Jeff SaturdayJ.\xa0Saturday', 'Matt SchaubM.\xa0Schaub',
#        'Larry FitzgeraldL.\xa0Fitzgerald', 'Tony FisherT.\xa0Fisher',
#        'Mike BartrumM.\xa0Bartrum', 'Peerless PriceP.\xa0Price',
#        'Clinton PortisC.\xa0Portis', 'Keenan McCardellK.\xa0McCardell',
#        'Adam VinatieriA.\xa0Vinatieri', 'J.P. LosmanJ.\xa0Losman',
#        'Drew HensonD.\xa0Henson', 'Randy HymesR.\xa0Hymes',
#        'Ronald CurryR.\xa0Curry', 'Jim SorgiJ.\xa0Sorgi',
#        'Brooks BollingerB.\xa0Bollinger', 'John NavarreJ.\xa0Navarre',
#        'Paul EdingerP.\xa0Edinger',
#        'Adimchinobe EchemanduA.\xa0Echemandu',
#        'Cody PickettC.\xa0Pickett', 'Jeff WilkinsJ.\xa0Wilkins',
#        'Brian St. PierreB.\xa0St. Pierre', 'Philip RiversP.\xa0Rivers',
#        'Mike ScifresM.\xa0Scifres', 'Patrick CraytonP.\xa0Crayton',
#        'Kyle OrtonK.\xa0Orton', 'Matt JonesM.\xa0Jones',
#        'Arnaz BattleA.\xa0Battle', 'Dan OrlovskyD.\xa0Orlovsky',
#        'Alex SmithA.\xa0Smith', 'Seneca WallaceS.\xa0Wallace',
#        'Matt CasselM.\xa0Cassel', 'Aaron RodgersA.\xa0Rodgers',
#        'Marion BarberM.\xa0Barber', 'Matt MauckM.\xa0Mauck',
#        'Chris GardockiC.\xa0Gardocki', 'B.J. SanderB.\xa0Sander',
#        'DeShaun FosterD.\xa0Foster', 'Charlie FryeC.\xa0Frye',
#        'Kliff KingsburyK.\xa0Kingsbury',
#        'Ryan FitzpatrickR.\xa0Fitzpatrick',
#        'Domanick WilliamsD.\xa0Williams', 'Roscoe ParrishR.\xa0Parrish',
#        'Adam JonesA.\xa0Jones', 'Hunter SmithH.\xa0Smith',
#        'Mark ClaytonM.\xa0Clayton', 'Samkon GadoS.\xa0Gado',
#        'Tiki BarberT.\xa0Barber', 'Bradlee Van PeltB.\xa0Van Pelt',
#        'Quinn GrayQ.\xa0Gray', 'Bruce GradkowskiB.\xa0Gradkowski',
#        'Vince YoungV.\xa0Young', 'Thomas JonesT.\xa0Jones',
#        'Jon RyanJ.\xa0Ryan', 'Andrew WalterA.\xa0Walter',
#        'Ryan LongwellR.\xa0Longwell', 'Jerious NorwoodJ.\xa0Norwood',
#        'Matt LeinartM.\xa0Leinart', 'David AkersD.\xa0Akers',
#        'Kellen ClemensK.\xa0Clemens', 'Tony RomoT.\xa0Romo',
#        'Brodie CroyleB.\xa0Croyle', 'Reggie BushR.\xa0Bush',
#        'Wali LundyW.\xa0Lundy', 'Ronnie BrownR.\xa0Brown',
#        'Deion BranchD.\xa0Branch', 'Jason CampbellJ.\xa0Campbell',
#        'Hank BaskettH.\xa0Baskett', 'Derek AndersonD.\xa0Anderson',
#        'Tarvaris JacksonT.\xa0Jackson', 'Jay CutlerJ.\xa0Cutler',
#        'Joseph AddaiJ.\xa0Addai', 'Joshua CribbsJ.\xa0Cribbs',
#        'Kellen WinslowK.\xa0Winslow', 'Cleo LemonC.\xa0Lemon',
#        'Ben GrahamB.\xa0Graham', 'Brett BasanezB.\xa0Basanez',
#        'Carlyle HolidayC.\xa0Holiday', 'Lee EvansL.\xa0Evans',
#        'Larry JohnsonL.\xa0Johnson', 'Michael RobinsonM.\xa0Robinson',
#        'Jared LorenzenJ.\xa0Lorenzen', "J.T. O'SullivanJ.\xa0O'Sullivan",
#        'Trent EdwardsT.\xa0Edwards', 'Kevin KolbK.\xa0Kolb',
#        'Robbie GouldR.\xa0Gould', 'Matt MooreM.\xa0Moore',
#        'Matt GutierrezM.\xa0Gutierrez', 'Brandon MarshallB.\xa0Marshall',
#        'Marshawn LynchM.\xa0Lynch', 'Willie ParkerW.\xa0Parker',
#        'Steven JacksonS.\xa0Jackson', 'John BeckJ.\xa0Beck',
#        'Sidney RiceS.\xa0Rice', 'Chris KluweC.\xa0Kluwe',
#        'Chester TaylorC.\xa0Taylor', 'Tyler ThigpenT.\xa0Thigpen',
#        'Eddie KennisonE.\xa0Kennison', 'JaMarcus RussellJ.\xa0Russell',
#        'Greg LewisG.\xa0Lewis', 'Brock BerlinB.\xa0Berlin',
#        'Shaun HillS.\xa0Hill', 'Troy SmithT.\xa0Smith',
#        'Brad SmithB.\xa0Smith', 'Daniel SepulvedaD.\xa0Sepulveda',
#        'Adrian PetersonA.\xa0Peterson', 'Devin HesterD.\xa0Hester',
#        'Brady QuinnB.\xa0Quinn', 'Leon WashingtonL.\xa0Washington',
#        'Joe FlaccoJ.\xa0Flacco', 'Matt RyanM.\xa0Ryan',
#        'Eddie RoyalE.\xa0Royal', 'Marques HagansM.\xa0Hagans',
#        'Chad HenneC.\xa0Henne', "Kevin O'ConnellK.\xa0O'Connell",
#        'Jerheme UrbanJ.\xa0Urban', 'Matt FlynnM.\xa0Flynn',
#        'Jordan PalmerJ.\xa0Palmer', 'Dirk JohnsonD.\xa0Johnson',
#        'J.J. ArringtonJ.\xa0Arrington', 'Earnest GrahamE.\xa0Graham',
#        'Mark BradleyM.\xa0Bradley', 'Drew StantonD.\xa0Stanton',
#        'Darren McFaddenD.\xa0McFadden', 'Donnie JonesD.\xa0Jones',
#        'Michael BushM.\xa0Bush', 'Lance MooreL.\xa0Moore',
#        'DeSean JacksonD.\xa0Jackson', 'Dennis DixonD.\xa0Dixon',
#        'Jason WittenJ.\xa0Witten', 'Pat WhiteP.\xa0White',
#        'Matthew StaffordM.\xa0Stafford', 'Michael ClaytonM.\xa0Clayton',
#        'Mark SanchezM.\xa0Sanchez', 'Micheal SpurlockM.\xa0Spurlock',
#        'Josh JohnsonJ.\xa0Johnson', 'Steve WeatherfordS.\xa0Weatherford',
#        'Brian HoyerB.\xa0Hoyer', 'Caleb HanieC.\xa0Hanie',
#        'Josh FreemanJ.\xa0Freeman', 'Josh BrownJ.\xa0Brown',
#        'Reggie WayneR.\xa0Wayne', 'Chris JohnsonC.\xa0Johnson',
#        'Tatum BellT.\xa0Bell', 'Shaud WilliamsS.\xa0Williams',
#        'Charles AliC.\xa0Ali', 'Ingle MartinI.\xa0Martin',
#        'Fred JacksonF.\xa0Jackson', 'Braylon EdwardsB.\xa0Edwards',
#        'Ray RiceR.\xa0Rice', 'Andrew PinnockA.\xa0Pinnock',
#        'John David WashingtonJ.\xa0Washington', 'Shane BoydS.\xa0Boyd',
#        'Phil DawsonP.\xa0Dawson', 'Chris BrownC.\xa0Brown',
#        'Legedu NaaneeL.\xa0Naanee', 'Keith NullK.\xa0Null',
#        'Brian BrohmB.\xa0Brohm', 'Curtis PainterC.\xa0Painter',
#        'Santonio HolmesS.\xa0Holmes', 'Tim CastilleT.\xa0Castille',
#        'Jimmy ClausenJ.\xa0Clausen', 'Sam BradfordS.\xa0Bradford',
#        'Max HallM.\xa0Hall', 'Jahvid BestJ.\xa0Best',
#        'Colt McCoyC.\xa0McCoy', 'Peyton HillisP.\xa0Hillis',
#        'Sam KochS.\xa0Koch', 'Chase DanielC.\xa0Daniel',
#        'Tony PikeT.\xa0Pike', 'Steve BreastonS.\xa0Breaston',
#        'Charlie WhitehurstC.\xa0Whitehurst', 'Tim TebowT.\xa0Tebow',
#        'Rusty SmithR.\xa0Smith', 'Maurice Jones-DrewM.\xa0Jones-Drew',
#        'Chad JohnsonC.\xa0Johnson', 'John SkeltonJ.\xa0Skelton',
#        'Armanti EdwardsA.\xa0Edwards', 'Joe WebbJ.\xa0Webb',
#        'Tyler PalkoT.\xa0Palko', 'Stefan LoganS.\xa0Logan',
#        'Stephen McGeeS.\xa0McGee', 'Mohamed MassaquoiM.\xa0Massaquoi',
#        'Brandon LaFellB.\xa0LaFell', 'Levi BrownL.\xa0Brown',
#        "Le'Veon BellL.\xa0Bell", 'Riley DixonR.\xa0Dixon',
#        'Marqise LeeM.\xa0Lee', 'Dontari PoeD.\xa0Poe',
#        'Dez BryantD.\xa0Bryant', 'Antonio MorrisonA.\xa0Morrison',
#        'David FalesD.\xa0Fales', 'Cameron MeredithC.\xa0Meredith',
#        'Cardale JonesC.\xa0Jones', 'Pharoh CooperP.\xa0Cooper',
#        'Connor CookC.\xa0Cook'], dtype=object)

# %% [markdown]
# There are 13,187 unique QB values.

# %%
df['qb'].value_counts().head()
# Out:
# Peyton ManningP. Manning    265
# Tom BradyT. Brady           237
# Brett FavreB. Favre         235
# Drew BreesD. Brees          232
# Eli ManningE. Manning       199
# Name: qb, dtype: int64

# %% [markdown]
# Peyton Manning played in the most games from 1996-2016.

# %%
qb_rating_means = df.groupby(by='qb')['rate'].mean().sort_values(ascending=False)
qb_rating_means.head()
# Out:
# qb
# Josh MillerJ. Miller          158.3
# Tyrone WheatleyT. Wheatley    158.3
# Brandon BanksB. Banks         158.3
# Ken DilgerK. Dilger           158.3
# Doug BaldwinD. Baldwin        158.3
# Name: rate, dtype: float64

# %% [markdown]
# Looks like a few people have a perfect QB rating of 158.3.

# %% [markdown]
# ### 2.7.2 CMP Column<a id='2.7.2_CMP_Column'></a>

# %%
df['cmp'].dtypes
# Out:
# dtype('int64')

# %% [markdown]
# It is an integer. Which it should be!

# %%
df['cmp'].max()
# Out:
# 58

# %%
df['cmp'].min()
# Out:
# -6

# %% [markdown]
# Here we will have to get rid of the -6 value because it is impossible to throw -6 completions. Lets see if there are any other rows with a value below 0.

# %%
df['cmp'].max()-df['cmp'].min()
# Out:
# 64

# %%
df[df['cmp'].isin([-6,-5,-4,-3,-2,-1])]
# Out:
#                                  qb  cmp  att  comp %  yds  td  int  rate  \
# 8597        Chris GreisenC. Greisen   -1    1  -100.0   -1   0    0   0.0
# 8602  LaBrandon ToefieldL. Toefield   -1    3   -33.3    0   0    0   0.0
# 8647   Brooks BollingerB. Bollinger   -6    3  -200.0   -2   0    0   0.0
#
#       long  sack  game_points  ypa  ypc  td_per_cmp  td_per_att  loss_yds  \
# 8597     0     0           24 -1.0  1.0        -0.0         0.0         0
# 8602     0     0            6  1.0  0.3        -0.0         0.0         0
# 8647     0     0           34  0.0  0.3        -0.0         0.0         0
#
#      home_away  year
# 8597      away  2009
# 8602      home  2009
# 8647      away  2009

# %% [markdown]
# We will have to get rid of these three rows as they are incorrect.

# %%
df.drop([8597,8602,8647], axis=0, inplace=True)

# %%
df['cmp'].min()
# Out:
# 0

# %% [markdown]
# It worked!

# %%
df['cmp'].mean()
# Out:
# 16.122515551509636

# %%
df['cmp'].median()
# Out:
# 17.0

# %%
df['cmp'].mode()
# Out:
# 0    0
# dtype: int64

# %%
df['cmp'].std()
# Out:
# 8.767621606454494

# %%
df['cmp'].unique()
# Out:
# array([25, 16,  5, 17, 23, 13, 20,  1, 21, 19, 12,  9,  3,  0, 18,  7,  4,
#        24, 11, 22, 14, 27, 15, 26,  2, 10,  6,  8, 37, 29, 28, 32, 31, 33,
#        30, 35, 34, 38, 42, 36, 39, 40, 43, 46, 58, 41], dtype=int64)

# %%
df['cmp'].value_counts().head()
# Out:
# 0     719
# 18    687
# 17    676
# 1     666
# 21    661
# Name: cmp, dtype: int64

# %% [markdown]
# The mean and median are very close. The most frequent number of completions is 0. The standard deviation is pretty spread out. We have a unique range of values from 0-58.

# %% [markdown]
# ### 2.7.3 ATT Column<a id='2.7.3_ATT_Column'></a>

# %%
df['att'].dtypes
# Out:
# dtype('int64')

# %%
df['att'].max()
# Out:
# 69

# %%
df['att'].min()
# Out:
# 0

# %%
df['att'].mean()
# Out:
# 26.877712031558186

# %%
df['att'].median()
# Out:
# 29.0

# %%
df['att'].mode()
# Out:
# 0    1
# dtype: int64

# %%
df['att'].value_counts().head()
# Out:
# 1     1003
# 30     495
# 33     479
# 35     474
# 34     472
# Name: att, dtype: int64

# %%
df['att'].std()
# Out:
# 13.581235442088403

# %%
df['att'].unique()
# Out:
# array([38, 25,  8, 35, 31, 40, 41,  1, 23, 14, 37, 29, 26, 33, 34, 17,  4,
#         2, 27, 30, 22, 13, 12, 24, 21, 32, 20, 46, 19,  3, 28, 11,  6,  0,
#        18, 44, 39, 36,  5,  7, 42, 54, 58, 16, 45, 10, 43, 48, 50, 15, 61,
#        52, 51,  9, 49, 59, 47, 60, 53, 56, 57, 63, 55, 69, 62, 68, 64, 67,
#        65], dtype=int64)

# %% [markdown]
# The mean and median are relatively close. One attempt is the most out of the value counts. The standard deviation is pretty spread out as well. We have a unique range of values from 0-69.

# %% [markdown]
# ### 2.7.4 Comp % Column<a id='2.7.4_Comp_%_Column'></a>

# %%
#yds into a int
df['yds']=df.yds.astype(int)



#replace all sack NaN values with 0
df['sack'] = df['sack'].fillna(0)
#sack into int
df['sack']=df.sack.astype(int)



#replace all comp % NaN values with 0
df['comp %'] = df['comp %'].fillna(0)



#replace all td per att NaN values with 0
df['td_per_att'] = df['td_per_att'].fillna(0)

#replace all loss yds NaN values with 0
df['loss_yds'] = df['loss_yds'].fillna(0)
#loss_yds into int
df['loss_yds']=df.loss_yds.astype(int)

# %%
df.T.describe()
# Out:
#         0      1      2      3                        4      \
# count      18     18     18     18                       18
# unique     15     17     15     15                       18
# top         0      0      0      0  Kerry CollinsK. Collins
# freq        4      2      4      4                        1
#
#                      5      6      7      8      9      ...  13178 13179  \
# count                   18     18     18     18     18  ...     18    18
# unique                  18     16     17      9     17  ...      9     6
# top     Jeff BlakeJ. Blake      0     13      0      1  ...      0     0
# freq                     1      3      2      6      2  ...      6    12
#
#         13180  13181  13182  13183  13184  13185  13186  \
# count      18     18     18     18     18     18     18
# unique     17     12     17     16     16     17     15
# top         1      0      0      2      2      1      0
# freq        2      6      2      2      2      2      4
#
#                                 13187
# count                              18
# unique                             18
# top     Colin KaepernickC. Kaepernick
# freq                                1
#
# [4 rows x 13188 columns]

# %%
#check if any QBs didnt attempt a pass/null values for a qb.
df['att'].isnull().values.any()
# Out:
# False

# %%
df['long'].isnull().values.any()
# Out:
# False

# %%
print(type(df['sack']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
df['year'].isnull().values.any()
# Out:
# False

# %%
df['long'].dtypes
# Out:
# dtype('int32')

# %%
df['sack'].dtypes
# Out:
# dtype('int32')
